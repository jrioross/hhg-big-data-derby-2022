# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from geopy.distance import geodesic
import utm
import math
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# #### Bringing in all the datasets

# %%
races = pd.read_csv('../data/nyra_race_table.csv')
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   track_id         2000 non-null   object
#  1   race_date        2000 non-null   object
#  2   race_number      2000 non-null   int64
#  3   distance_id      2000 non-null   int64
#  4   course_type      2000 non-null   object
#  5   track_condition  2000 non-null   object
#  6   run_up_distance  2000 non-null   int64
#  7   race_type        2000 non-null   object
#  8   purse            2000 non-null   int64
#  9   post_time        2000 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 156.4+ KB

# %%
starts = pd.read_csv('../data/nyra_start_table.csv')
starts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14915 entries, 0 to 14914
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   track_id        14915 non-null  object
#  1   race_date       14915 non-null  object
#  2   race_number     14915 non-null  int64
#  3   program_number  14915 non-null  object
#  4   weight_carried  14915 non-null  int64
#  5   jockey          14915 non-null  object
#  6   odds            14915 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 815.8+ KB

# %%
h_id = pd.read_csv('../data/horse_ids.csv')
h_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14916 entries, 0 to 14915
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       14916 non-null  int64
#  1   track_id         14916 non-null  object
#  2   race_date        14916 non-null  object
#  3   race             14916 non-null  int64
#  4   program_number   14916 non-null  object
#  5   horse_id         14916 non-null  int64
#  6   finishing_place  14916 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 815.8+ KB

# %%
h_names = pd.read_csv('../data/horse_names.csv')
h_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4638 entries, 0 to 4637
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4638 non-null   int64
#  1   horse_id    4638 non-null   int64
#  2   horse_name  4638 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 108.8+ KB

# %%
tracking = pd.read_csv('../data/nyra_tracking_table.csv')
tracking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5228430 entries, 0 to 5228429
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   track_id        object
#  1   race_date       object
#  2   race_number     int64
#  3   program_number  object
#  4   trakus_index    int64
#  5   latitude        float64
#  6   longitude       float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 279.2+ MB

# %% [markdown]
# ##### Merging all data sets

# %%
# merging Horse ID and Horse Name data sets
h_id = h_id[['track_id', 'race_date', 'race', 'program_number', 'horse_id', 'finishing_place']]
h_names = h_names[['horse_id', 'horse_name']]
horses = pd.merge(h_id, h_names, how='left', on='horse_id')
horses = horses.rename(columns = {'race' : 'race_number'})

# Adding in Starts data
starts['race_date'] = pd.to_datetime(starts['race_date'])
horses['race_date'] = pd.to_datetime(horses['race_date'])
# strip spaces in the starts program_number column
starts['program_number'] = starts['program_number'].str.strip()
# merge
st_h = pd.merge(starts, horses, how='outer', on=['track_id', 'race_date', 'race_number', 'program_number'])
st_h = st_h.dropna(subset='odds')

# Adding in race details
races['race_date'] = pd.to_datetime(races['race_date'])
ra_st_h = pd.merge(st_h, races, how='left', on=['track_id', 'race_date', 'race_number'])

# Adding in tracking data
tracking['program_number'] = tracking['program_number'].str.strip()
tracking['race_date'] = pd.to_datetime(tracking['race_date'])
full = pd.merge(ra_st_h, tracking, how='left', on=['track_id', 'race_date', 'race_number', 'program_number'])

#Because races that include jumps are so drastically different than flat races, and such a comparatively small proportion of races
#we decided to drop those from our data set for the majority of our analysis
full = full.loc[full['course_type'] != 'M']

full = full.sort_values(['track_id', 'race_date', 'race_number', 'program_number', 'trakus_index']).reset_index(drop=True)

full.head()
# Out:
#   track_id  race_date  race_number program_number  weight_carried  \
# 0      AQU 2019-01-01            1              1           123.0
# 1      AQU 2019-01-01            1              1           123.0
# 2      AQU 2019-01-01            1              1           123.0
# 3      AQU 2019-01-01            1              1           123.0
# 4      AQU 2019-01-01            1              1           123.0
#
#         jockey   odds  horse_id  finishing_place        horse_name  \
# 0  Dylan Davis  130.0         1                2  Sounds Delicious
# 1  Dylan Davis  130.0         1                2  Sounds Delicious
# 2  Dylan Davis  130.0         1                2  Sounds Delicious
# 3  Dylan Davis  130.0         1                2  Sounds Delicious
# 4  Dylan Davis  130.0         1                2  Sounds Delicious
#
#    distance_id course_type track_condition  run_up_distance race_type  purse  \
# 0          650           D             MY                36       AOC  80000
# 1          650           D             MY                36       AOC  80000
# 2          650           D             MY                36       AOC  80000
# 3          650           D             MY                36       AOC  80000
# 4          650           D             MY                36       AOC  80000
#
#    post_time  trakus_index   latitude  longitude
# 0       1220             1  40.669401 -73.829205
# 1       1220             2  40.669405 -73.829203
# 2       1220             3  40.669411 -73.829200
# 3       1220             4  40.669421 -73.829196
# 4       1220             5  40.669433 -73.829190

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5162881 entries, 0 to 5162880
# Data columns (total 20 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   track_id         object
#  1   race_date        datetime64[ns]
#  2   race_number      int64
#  3   program_number   object
#  4   weight_carried   float64
#  5   jockey           object
#  6   odds             float64
#  7   horse_id         int64
#  8   finishing_place  int64
#  9   horse_name       object
#  10  distance_id      int64
#  11  course_type      object
#  12  track_condition  object
#  13  run_up_distance  int64
#  14  race_type        object
#  15  purse            int64
#  16  post_time        int64
#  17  trakus_index     int64
#  18  latitude         float64
#  19  longitude        float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(7)
# memory usage: 787.8+ MB

# %%
full['latitude'].describe()
# Out:
# count    5.162881e+06
# mean     4.118758e+01
# std      9.656976e-01
# min      4.066671e+01
# 25%      4.067341e+01
# 50%      4.071387e+01
# 75%      4.071732e+01
# max      4.307399e+01
# Name: latitude, dtype: float64

# %%
geodesic([full['latitude'][1], full['longitude'][1]], [full['latitude'][0], full['longitude'][0]]).feet

# %%
full['p_lat'] = full.groupby(['track_id', 'race_date', 'race_number', 
                              'program_number'])['latitude'].shift(1)
full['p_lon'] = full.groupby(['track_id', 'race_date', 'race_number', 
                              'program_number'])['longitude'].shift(1)
full
# Out:
#         track_id  race_date  race_number program_number  weight_carried  \
# 0            AQU 2019-01-01            1              1           123.0
# 1            AQU 2019-01-01            1              1           123.0
# 2            AQU 2019-01-01            1              1           123.0
# 3            AQU 2019-01-01            1              1           123.0
# 4            AQU 2019-01-01            1              1           123.0
# ...          ...        ...          ...            ...             ...
# 5162876      SAR 2019-09-02           11              8           119.0
# 5162877      SAR 2019-09-02           11              8           119.0
# 5162878      SAR 2019-09-02           11              8           119.0
# 5162879      SAR 2019-09-02           11              8           119.0
# 5162880      SAR 2019-09-02           11              8           119.0
#
#               jockey   odds  horse_id  finishing_place        horse_name  ...  \
# 0        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 1        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 2        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 3        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 4        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# ...              ...    ...       ...              ...               ...  ...
# 5162876    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162877    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162878    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162879    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162880    Luis Saez  110.0      2295                6     Mine the Coin  ...
#
#          track_condition run_up_distance race_type  purse post_time  \
# 0                    MY               36       AOC  80000      1220
# 1                    MY               36       AOC  80000      1220
# 2                    MY               36       AOC  80000      1220
# 3                    MY               36       AOC  80000      1220
# 4                    MY               36       AOC  80000      1220
# ...                  ...             ...       ...    ...       ...
# 5162876              SY               32       MCL  40000       614
# 5162877              SY               32       MCL  40000       614
# 5162878              SY               32       MCL  40000       614
# 5162879              SY               32       MCL  40000       614
# 5162880              SY               32       MCL  40000       614
#
#          trakus_index   latitude  longitude      p_lat      p_lon
# 0                   1  40.669401 -73.829205        NaN        NaN
# 1                   2  40.669405 -73.829203  40.669401 -73.829205
# 2                   3  40.669411 -73.829200  40.669405 -73.829203
# 3                   4  40.669421 -73.829196  40.669411 -73.829200
# 4                   5  40.669433 -73.829190  40.669421 -73.829196
# ...               ...        ...        ...        ...        ...
# 5162876           329  43.071944 -73.771727  43.071955 -73.771696
# 5162877           330  43.071933 -73.771760  43.071944 -73.771727
# 5162878           331  43.071922 -73.771792  43.071933 -73.771760
# 5162879           332  43.071911 -73.771825  43.071922 -73.771792
# 5162880           333  43.071899 -73.771858  43.071911 -73.771825
#
# [5162881 rows x 22 columns]

# %%
pd.isna(full['p_lat'][1]) == False
# Out:
# True

# %%
full['seg_dist_yd'] = [geodesic([full['latitude'][i], full['longitude'][i]], 
                                              [full['p_lat'][i], full['p_lon'][i]]).feet/3 
                       if pd.isna(full['p_lat'][i]) == False else float('nan') for i in range(len(full))]

# %%
full
# Out:
#         track_id  race_date  race_number program_number  weight_carried  \
# 0            AQU 2019-01-01            1              1           123.0
# 1            AQU 2019-01-01            1              1           123.0
# 2            AQU 2019-01-01            1              1           123.0
# 3            AQU 2019-01-01            1              1           123.0
# 4            AQU 2019-01-01            1              1           123.0
# ...          ...        ...          ...            ...             ...
# 5162876      SAR 2019-09-02           11              8           119.0
# 5162877      SAR 2019-09-02           11              8           119.0
# 5162878      SAR 2019-09-02           11              8           119.0
# 5162879      SAR 2019-09-02           11              8           119.0
# 5162880      SAR 2019-09-02           11              8           119.0
#
#               jockey   odds  horse_id  finishing_place        horse_name  ...  \
# 0        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 1        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 2        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 3        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 4        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# ...              ...    ...       ...              ...               ...  ...
# 5162876    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162877    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162878    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162879    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162880    Luis Saez  110.0      2295                6     Mine the Coin  ...
#
#          run_up_distance race_type  purse  post_time trakus_index   latitude  \
# 0                     36       AOC  80000       1220            1  40.669401
# 1                     36       AOC  80000       1220            2  40.669405
# 2                     36       AOC  80000       1220            3  40.669411
# 3                     36       AOC  80000       1220            4  40.669421
# 4                     36       AOC  80000       1220            5  40.669433
# ...                  ...       ...    ...        ...          ...        ...
# 5162876               32       MCL  40000        614          329  43.071944
# 5162877               32       MCL  40000        614          330  43.071933
# 5162878               32       MCL  40000        614          331  43.071922
# 5162879               32       MCL  40000        614          332  43.071911
# 5162880               32       MCL  40000        614          333  43.071899
#
#          longitude      p_lat      p_lon  seg_dist_yd
# 0       -73.829205        NaN        NaN          NaN
# 1       -73.829203  40.669401 -73.829205     0.578236
# 2       -73.829200  40.669405 -73.829203     0.802984
# 3       -73.829196  40.669411 -73.829200     1.213156
# 4       -73.829190  40.669421 -73.829196     1.507487
# ...            ...        ...        ...          ...
# 5162876 -73.771727  43.071955 -73.771696     3.061578
# 5162877 -73.771760  43.071944 -73.771727     3.167151
# 5162878 -73.771792  43.071933 -73.771760     3.203113
# 5162879 -73.771825  43.071922 -73.771792     3.247697
# 5162880 -73.771858  43.071911 -73.771825     3.188410
#
# [5162881 rows x 23 columns]

# %%
full['seg_speed_yd/s'] = full['seg_dist_yd']*4

full['seg_mph'] = 2.0454545454545 * full['seg_speed_yd/s']

full['cum_dist_yd'] = full.groupby(['track_id', 'race_date', 'race_number', 
                              'program_number'])['seg_dist_yd'].cumsum()

full['avg_speed_yd/s'] = full['cum_dist_yd'] / (full['trakus_index']/4)

full['avg_mph'] = 2.0454545454545 * full['avg_speed_yd/s']

full['seg_accel_yd/s2'] = 4 * full['seg_speed_yd/s'].diff()

full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5162881 entries, 0 to 5162880
# Data columns (total 29 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   track_id         object
#  1   race_date        datetime64[ns]
#  2   race_number      int64
#  3   program_number   object
#  4   weight_carried   float64
#  5   jockey           object
#  6   odds             float64
#  7   horse_id         int64
#  8   finishing_place  int64
#  9   horse_name       object
#  10  distance_id      int64
#  11  course_type      object
#  12  track_condition  object
#  13  run_up_distance  int64
#  14  race_type        object
#  15  purse            int64
#  16  post_time        int64
#  17  trakus_index     int64
#  18  latitude         float64
#  19  longitude        float64
#  20  p_lat            float64
#  21  p_lon            float64
#  22  seg_dist_yd      float64
#  23  seg_speed_yd/s   float64
#  24  seg_mph          float64
#  25  cum_dist_yd      float64
#  26  avg_speed_yd/s   float64
#  27  avg_mph          float64
#  28  seg_accel_yd/s2  float64
# dtypes: datetime64[ns](1), float64(13), int64(8), object(7)
# memory usage: 1.1+ GB

# %%
full = full[['track_id', 'race_date', 'race_number', 'program_number', 'horse_id', 'weight_carried', 
                'jockey', 'odds', 'finishing_place', 'horse_name', 'course_type', 'track_condition',
                'race_type', 'purse', 'post_time', 'latitude', 'longitude', 'p_lat', 'p_lon', 'distance_id', 
                'run_up_distance', 'trakus_index', 'seg_dist_yd', 'seg_speed_yd/s', 'seg_mph', 'cum_dist_yd', 
                'avg_speed_yd/s', 'avg_mph', 'seg_accel_yd/s2']]

# %%
import pickle

with open('../data/full_race_data.pickle', 'wb') as file:
    pickle.dump(full, file)

# %%
full.head(50)
# Out:
#    track_id  race_date  race_number program_number  horse_id  weight_carried  \
# 0       AQU 2019-01-01            1              1         1   123.000000000
# 1       AQU 2019-01-01            1              1         1   123.000000000
# 2       AQU 2019-01-01            1              1         1   123.000000000
# 3       AQU 2019-01-01            1              1         1   123.000000000
# 4       AQU 2019-01-01            1              1         1   123.000000000
# 5       AQU 2019-01-01            1              1         1   123.000000000
# 6       AQU 2019-01-01            1              1         1   123.000000000
# 7       AQU 2019-01-01            1              1         1   123.000000000
# 8       AQU 2019-01-01            1              1         1   123.000000000
# 9       AQU 2019-01-01            1              1         1   123.000000000
# 10      AQU 2019-01-01            1              1         1   123.000000000
# 11      AQU 2019-01-01            1              1         1   123.000000000
# 12      AQU 2019-01-01            1              1         1   123.000000000
# 13      AQU 2019-01-01            1              1         1   123.000000000
# 14      AQU 2019-01-01            1              1         1   123.000000000
# 15      AQU 2019-01-01            1              1         1   123.000000000
# 16      AQU 2019-01-01            1              1         1   123.000000000
# 17      AQU 2019-01-01            1              1         1   123.000000000
# 18      AQU 2019-01-01            1              1         1   123.000000000
# 19      AQU 2019-01-01            1              1         1   123.000000000
# 20      AQU 2019-01-01            1              1         1   123.000000000
# 21      AQU 2019-01-01            1              1         1   123.000000000
# 22      AQU 2019-01-01            1              1         1   123.000000000
# 23      AQU 2019-01-01            1              1         1   123.000000000
# 24      AQU 2019-01-01            1              1         1   123.000000000
# 25      AQU 2019-01-01            1              1         1   123.000000000
# 26      AQU 2019-01-01            1              1         1   123.000000000
# 27      AQU 2019-01-01            1              1         1   123.000000000
# 28      AQU 2019-01-01            1              1         1   123.000000000
# 29      AQU 2019-01-01            1              1         1   123.000000000
# 30      AQU 2019-01-01            1              1         1   123.000000000
# 31      AQU 2019-01-01            1              1         1   123.000000000
# 32      AQU 2019-01-01            1              1         1   123.000000000
# 33      AQU 2019-01-01            1              1         1   123.000000000
# 34      AQU 2019-01-01            1              1         1   123.000000000
# 35      AQU 2019-01-01            1              1         1   123.000000000
# 36      AQU 2019-01-01            1              1         1   123.000000000
# 37      AQU 2019-01-01            1              1         1   123.000000000
# 38      AQU 2019-01-01            1              1         1   123.000000000
# 39      AQU 2019-01-01            1              1         1   123.000000000
# 40      AQU 2019-01-01            1              1         1   123.000000000
# 41      AQU 2019-01-01            1              1         1   123.000000000
# 42      AQU 2019-01-01            1              1         1   123.000000000
# 43      AQU 2019-01-01            1              1         1   123.000000000
# 44      AQU 2019-01-01            1              1         1   123.000000000
# 45      AQU 2019-01-01            1              1         1   123.000000000
# 46      AQU 2019-01-01            1              1         1   123.000000000
# 47      AQU 2019-01-01            1              1         1   123.000000000
# 48      AQU 2019-01-01            1              1         1   123.000000000
# 49      AQU 2019-01-01            1              1         1   123.000000000
#
#          jockey          odds  finishing_place        horse_name  ...  \
# 0   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 1   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 2   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 3   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 4   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 5   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 6   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 7   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 8   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 9   Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 10  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 11  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 12  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 13  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 14  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 15  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 16  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 17  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 18  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 19  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 20  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 21  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 22  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 23  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 24  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 25  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 26  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 27  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 28  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 29  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 30  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 31  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 32  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 33  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 34  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 35  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 36  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 37  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 38  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 39  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 40  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 41  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 42  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 43  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 44  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 45  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 46  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 47  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 48  Dylan Davis 130.000000000                2  Sounds Delicious  ...
# 49  Dylan Davis 130.000000000                2  Sounds Delicious  ...
#
#    distance_id run_up_distance trakus_index  seg_dist_yd  seg_speed_yd/s  \
# 0          650              36            1          NaN             NaN
# 1          650              36            2  0.578236321     2.312945286
# 2          650              36            3  0.802984235     3.211936942
# 3          650              36            4  1.213156191     4.852624763
# 4          650              36            5  1.507487478     6.029949911
# 5          650              36            6  1.964884405     7.859537622
# 6          650              36            7  2.273433210     9.093732839
# 7          650              36            8  2.767879900    11.071519601
# 8          650              36            9  3.125547898    12.502191592
# 9          650              36           10  3.153168160    12.612672642
# 10         650              36           11  3.501020895    14.004083582
# 11         650              36           12  3.873852760    15.495411039
# 12         650              36           13  3.975507667    15.902030667
# 13         650              36           14  4.186603052    16.746412208
# 14         650              36           15  4.170175428    16.680701711
# 15         650              36           16  4.545403977    18.181615910
# 16         650              36           17  4.411981530    17.647926120
# 17         650              36           18  4.511653414    18.046613656
# 18         650              36           19  4.740361024    18.961444094
# 19         650              36           20  4.920945578    19.683782312
# 20         650              36           21  4.958432534    19.833730134
# 21         650              36           22  4.925680347    19.702721386
# 22         650              36           23  4.950525871    19.802103483
# 23         650              36           24  5.169241182    20.676964727
# 24         650              36           25  5.218463049    20.873852196
# 25         650              36           26  5.355149015    21.420596060
# 26         650              36           27  5.430637164    21.722548657
# 27         650              36           28  5.424101960    21.696407841
# 28         650              36           29  5.372623561    21.490494244
# 29         650              36           30  5.482905129    21.931620514
# 30         650              36           31  5.632775943    22.531103771
# 31         650              36           32  5.621995129    22.487980517
# 32         650              36           33  5.633079678    22.532318713
# 33         650              36           34  5.523758155    22.095032618
# 34         650              36           35  5.658391978    22.633567912
# 35         650              36           36  5.653025855    22.612103418
# 36         650              36           37  5.657629375    22.630517501
# 37         650              36           38  5.775983973    23.103935892
# 38         650              36           39  5.711594427    22.846377707
# 39         650              36           40  5.715021125    22.860084500
# 40         650              36           41  5.784071759    23.136287035
# 41         650              36           42  5.693409034    22.773636138
# 42         650              36           43  5.729497316    22.917989263
# 43         650              36           44  5.706698078    22.826792313
# 44         650              36           45  5.862915807    23.451663229
# 45         650              36           46  5.763067845    23.052271381
# 46         650              36           47  5.740006058    22.960024233
# 47         650              36           48  5.918143166    23.672572664
# 48         650              36           49  5.722262326    22.889049305
# 49         650              36           50  5.804354532    23.217418129
#
#         seg_mph   cum_dist_yd  avg_speed_yd/s      avg_mph  seg_accel_yd/s2
# 0           NaN           NaN             NaN          NaN              NaN
# 1   4.731024448   0.578236321     1.156472643  2.365512224              NaN
# 2   6.569871017   1.381220557     1.841627409  3.766965155      3.595966625
# 3   9.925823379   2.594376748     2.594376748  5.306679711      6.562751285
# 4  12.333988454   4.101864225     3.281491380  6.712141460      4.709300592
# 5  16.076326953   6.066748631     4.044499087  8.272839042      7.318350842
# 6  18.600817171   8.340181841     4.765818195  9.748264489      4.936780870
# 7  22.646290092  11.108061741     5.554030870 11.360517689      7.911147046
# 8  25.572664620  14.233609639     6.326048728 12.939645126      5.722687966
# 9  25.798648585  17.386777799     6.954711120 14.225545472      0.441924198
# 10 28.644716417  20.887798695     7.595563162 15.536379194      5.565643761
# 11 31.695158944  24.761651454     8.253883818 16.882944173      5.965309831
# 12 32.526880909  28.737159121     8.842202806 18.086323922      1.626478509
# 13 34.254024970  32.923762173     9.406789192 19.241159711      3.377526164
# 14 34.119617136  37.093937601     9.891716694 20.233056873     -0.262841986
# 15 37.189668906  41.639341578    10.409835395 21.292845125      6.003656795
# 16 36.098030700  46.051323108    10.835605437 22.163738394     -2.134759160
# 17 36.913527933  50.562976522    11.236217005 22.983171146      1.594750144
# 18 38.784772010  55.303337546    11.642807904 23.814834350      3.659321752
# 19 40.262282003  60.224283124    12.044856625 24.637206732      2.889352874
# 20 40.568993456  65.182715657    12.415755363 25.395863243      0.599791287
# 21 40.301021018  70.108396004    12.746981092 26.073370415     -0.524034991
# 22 40.504302578  75.058921874    13.053725543 26.700802248      0.397528384
# 23 42.293791487  80.228163056    13.371360509 27.350510133      3.499444978
# 24 42.696515856  85.446626105    13.671460177 27.964350362      0.787549876
# 25 43.814855577  90.801775120    13.969503865 28.573985178      2.186975455
# 26 44.432485890  96.232412285    14.256653672 29.161337056      1.207810389
# 27 44.379016038 101.656514245    14.522359178 29.704825591     -0.104563266
# 28 43.957829136 107.029137806    14.762639697 30.196308472     -0.823654385
# 29 44.860132870 112.512042934    15.001605725 30.685102618      1.764505080
# 30 46.086348623 118.144818877    15.244492758 31.181917006      2.397933028
# 31 45.998141966 123.766814006    15.470851751 31.644924036     -0.172493019
# 32 46.088833730 129.399893684    15.684835598 32.082618269      0.177352784
# 33 45.194384901 134.923651839    15.873370805 32.468258464     -1.749144376
# 34 46.295934366 140.582043817    16.066519293 32.863334918      2.154141175
# 35 46.252029719 146.235069672    16.248341075 33.235243107     -0.085857976
# 36 46.289694888 151.892699047    16.420832329 33.588066128      0.073656330
# 37 47.258050689 157.668683020    16.596703476 33.947802564      1.893673566
# 38 46.731227127 163.380277447    16.756951533 34.275582681     -1.030232743
# 39 46.759263751 169.095298572    16.909529857 34.587674708      0.054827175
# 40 47.324223481 174.879370331    17.061401983 34.898322239      1.104810138
# 41 46.582437554 180.572779365    17.197407559 35.176515461     -1.450603589
# 42 46.877705310 186.302276681    17.330444342 35.448636155      0.577412501
# 43 46.691166096 192.008974759    17.455361342 35.704148199     -0.364787797
# 44 47.969311151 197.871890566    17.588612495 35.976707376      2.499483663
# 45 47.152373280 203.634958412    17.707387688 36.219656634     -1.597567391
# 46 46.963685931 209.374964470    17.819145912 36.448253002     -0.368988594
# 47 48.421171359 215.293107636    17.941092303 36.697688802      2.850193725
# 48 46.818509943 221.015369962    18.042071017 36.904236172     -3.134093435
# 49 47.490173446 226.819724495    18.145577960 37.115954917      1.313475295
#
# [50 rows x 29 columns]
