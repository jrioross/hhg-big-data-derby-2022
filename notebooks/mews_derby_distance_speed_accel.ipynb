# %%
import pandas as pd
import numpy as np
from geopy.distance import geodesic
import math

# %% [markdown]
# #### Bringing in all the datasets

# %%
races = pd.read_csv('../data/nyra_race_table.csv')
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   track_id         2000 non-null   object
#  1   race_date        2000 non-null   object
#  2   race_number      2000 non-null   int64
#  3   distance_id      2000 non-null   int64
#  4   course_type      2000 non-null   object
#  5   track_condition  2000 non-null   object
#  6   run_up_distance  2000 non-null   int64
#  7   race_type        2000 non-null   object
#  8   purse            2000 non-null   int64
#  9   post_time        2000 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 156.4+ KB

# %%
starts = pd.read_csv('../data/nyra_start_table.csv')
starts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14915 entries, 0 to 14914
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   track_id        14915 non-null  object
#  1   race_date       14915 non-null  object
#  2   race_number     14915 non-null  int64
#  3   program_number  14915 non-null  object
#  4   weight_carried  14915 non-null  int64
#  5   jockey          14915 non-null  object
#  6   odds            14915 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 815.8+ KB

# %%
h_id = pd.read_csv('../data/horse_ids.csv')
h_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14916 entries, 0 to 14915
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       14916 non-null  int64
#  1   track_id         14916 non-null  object
#  2   race_date        14916 non-null  object
#  3   race             14916 non-null  int64
#  4   program_number   14916 non-null  object
#  5   horse_id         14916 non-null  int64
#  6   finishing_place  14916 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 815.8+ KB

# %%
h_names = pd.read_csv('../data/horse_names.csv')
h_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4638 entries, 0 to 4637
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4638 non-null   int64
#  1   horse_id    4638 non-null   int64
#  2   horse_name  4638 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 108.8+ KB

# %%
tracking = pd.read_csv('../data/nyra_tracking_table.csv')
tracking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5228430 entries, 0 to 5228429
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   track_id        object
#  1   race_date       object
#  2   race_number     int64
#  3   program_number  object
#  4   trakus_index    int64
#  5   latitude        float64
#  6   longitude       float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 279.2+ MB

# %% [markdown]
# ##### Merging all data sets

# %%
# merging Horse ID and Horse Name data sets
h_id = h_id[['track_id', 'race_date', 'race', 'program_number', 'horse_id', 'finishing_place']]
h_names = h_names[['horse_id', 'horse_name']]
horses = pd.merge(h_id, h_names, how='left', on='horse_id')
horses = horses.rename(columns = {'race' : 'race_number'})

# Adding in Starts data
starts['race_date'] = pd.to_datetime(starts['race_date'])
horses['race_date'] = pd.to_datetime(horses['race_date'])
# strip spaces in the starts program_number column
starts['program_number'] = starts['program_number'].str.strip()
# merge
st_h = pd.merge(starts, horses, how='outer', on=['track_id', 'race_date', 'race_number', 'program_number'])
st_h = st_h.dropna(subset='odds')

# Adding in race details
races['race_date'] = pd.to_datetime(races['race_date'])
ra_st_h = pd.merge(st_h, races, how='left', on=['track_id', 'race_date', 'race_number'])

# Adding in tracking data
tracking['program_number'] = tracking['program_number'].str.strip()
tracking['race_date'] = pd.to_datetime(tracking['race_date'])
full = pd.merge(ra_st_h, tracking, how='left', on=['track_id', 'race_date', 'race_number', 'program_number'])

#Because races that include jumps are so drastically different than flat races, and such a comparatively small proportion of races
#we decided to drop those from our data set for the majority of our analysis
full = full.loc[full['course_type'] != 'M']

full = full.sort_values(['track_id', 'race_date', 'race_number', 'program_number', 'trakus_index']).reset_index(drop=True)

full.head()
# Out:
#   track_id  race_date  race_number program_number  weight_carried  \
# 0      AQU 2019-01-01            1              1           123.0
# 1      AQU 2019-01-01            1              1           123.0
# 2      AQU 2019-01-01            1              1           123.0
# 3      AQU 2019-01-01            1              1           123.0
# 4      AQU 2019-01-01            1              1           123.0
#
#         jockey   odds  horse_id  finishing_place        horse_name  \
# 0  Dylan Davis  130.0         1                2  Sounds Delicious
# 1  Dylan Davis  130.0         1                2  Sounds Delicious
# 2  Dylan Davis  130.0         1                2  Sounds Delicious
# 3  Dylan Davis  130.0         1                2  Sounds Delicious
# 4  Dylan Davis  130.0         1                2  Sounds Delicious
#
#    distance_id course_type track_condition  run_up_distance race_type  purse  \
# 0          650           D             MY                36       AOC  80000
# 1          650           D             MY                36       AOC  80000
# 2          650           D             MY                36       AOC  80000
# 3          650           D             MY                36       AOC  80000
# 4          650           D             MY                36       AOC  80000
#
#    post_time  trakus_index   latitude  longitude
# 0       1220             1  40.669401 -73.829205
# 1       1220             2  40.669405 -73.829203
# 2       1220             3  40.669411 -73.829200
# 3       1220             4  40.669421 -73.829196
# 4       1220             5  40.669433 -73.829190

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5162881 entries, 0 to 5162880
# Data columns (total 20 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   track_id         object
#  1   race_date        datetime64[ns]
#  2   race_number      int64
#  3   program_number   object
#  4   weight_carried   float64
#  5   jockey           object
#  6   odds             float64
#  7   horse_id         int64
#  8   finishing_place  int64
#  9   horse_name       object
#  10  distance_id      int64
#  11  course_type      object
#  12  track_condition  object
#  13  run_up_distance  int64
#  14  race_type        object
#  15  purse            int64
#  16  post_time        int64
#  17  trakus_index     int64
#  18  latitude         float64
#  19  longitude        float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(7)
# memory usage: 787.8+ MB

# %%
#taking a look at the output of the geodesic function
#using feet because horse races are measured in fractions of a mile
geodesic([full['latitude'][0], full['longitude'][0]], [full['latitude'][1], full['longitude'][1]]).feet
# Out:
# 1.7347089642202558

# %%
#adding columns that give the next lat and lon for each horse
full['n_lat'] = full.groupby(['track_id', 'race_date', 'race_number', 
                              'program_number'])['latitude'].shift(-1)
full['n_lon'] = full.groupby(['track_id', 'race_date', 'race_number', 
                              'program_number'])['longitude'].shift(-1)
full
# Out:
#         track_id  race_date  race_number program_number  weight_carried  \
# 0            AQU 2019-01-01            1              1           123.0
# 1            AQU 2019-01-01            1              1           123.0
# 2            AQU 2019-01-01            1              1           123.0
# 3            AQU 2019-01-01            1              1           123.0
# 4            AQU 2019-01-01            1              1           123.0
# ...          ...        ...          ...            ...             ...
# 5162876      SAR 2019-09-02           11              8           119.0
# 5162877      SAR 2019-09-02           11              8           119.0
# 5162878      SAR 2019-09-02           11              8           119.0
# 5162879      SAR 2019-09-02           11              8           119.0
# 5162880      SAR 2019-09-02           11              8           119.0
#
#               jockey   odds  horse_id  finishing_place        horse_name  ...  \
# 0        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 1        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 2        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 3        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 4        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# ...              ...    ...       ...              ...               ...  ...
# 5162876    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162877    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162878    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162879    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162880    Luis Saez  110.0      2295                6     Mine the Coin  ...
#
#          track_condition run_up_distance race_type  purse post_time  \
# 0                    MY               36       AOC  80000      1220
# 1                    MY               36       AOC  80000      1220
# 2                    MY               36       AOC  80000      1220
# 3                    MY               36       AOC  80000      1220
# 4                    MY               36       AOC  80000      1220
# ...                  ...             ...       ...    ...       ...
# 5162876              SY               32       MCL  40000       614
# 5162877              SY               32       MCL  40000       614
# 5162878              SY               32       MCL  40000       614
# 5162879              SY               32       MCL  40000       614
# 5162880              SY               32       MCL  40000       614
#
#          trakus_index   latitude  longitude      n_lat      n_lon
# 0                   1  40.669401 -73.829205  40.669405 -73.829203
# 1                   2  40.669405 -73.829203  40.669411 -73.829200
# 2                   3  40.669411 -73.829200  40.669421 -73.829196
# 3                   4  40.669421 -73.829196  40.669433 -73.829190
# 4                   5  40.669433 -73.829190  40.669448 -73.829184
# ...               ...        ...        ...        ...        ...
# 5162876           329  43.071944 -73.771727  43.071933 -73.771760
# 5162877           330  43.071933 -73.771760  43.071922 -73.771792
# 5162878           331  43.071922 -73.771792  43.071911 -73.771825
# 5162879           332  43.071911 -73.771825  43.071899 -73.771858
# 5162880           333  43.071899 -73.771858        NaN        NaN
#
# [5162881 rows x 22 columns]

# %%
full['seg_dist_ft'] = [geodesic([full['latitude'][i], full['longitude'][i]], 
                                              [full['n_lat'][i], full['n_lon'][i]]).feet
                       if pd.isna(full['n_lat'][i]) == False else float('nan') for i in range(len(full))]

# %%
full
# Out:
#         track_id  race_date  race_number program_number  weight_carried  \
# 0            AQU 2019-01-01            1              1           123.0
# 1            AQU 2019-01-01            1              1           123.0
# 2            AQU 2019-01-01            1              1           123.0
# 3            AQU 2019-01-01            1              1           123.0
# 4            AQU 2019-01-01            1              1           123.0
# ...          ...        ...          ...            ...             ...
# 5162876      SAR 2019-09-02           11              8           119.0
# 5162877      SAR 2019-09-02           11              8           119.0
# 5162878      SAR 2019-09-02           11              8           119.0
# 5162879      SAR 2019-09-02           11              8           119.0
# 5162880      SAR 2019-09-02           11              8           119.0
#
#               jockey   odds  horse_id  finishing_place        horse_name  ...  \
# 0        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 1        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 2        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 3        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# 4        Dylan Davis  130.0         1                2  Sounds Delicious  ...
# ...              ...    ...       ...              ...               ...  ...
# 5162876    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162877    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162878    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162879    Luis Saez  110.0      2295                6     Mine the Coin  ...
# 5162880    Luis Saez  110.0      2295                6     Mine the Coin  ...
#
#          run_up_distance race_type  purse  post_time trakus_index   latitude  \
# 0                     36       AOC  80000       1220            1  40.669401
# 1                     36       AOC  80000       1220            2  40.669405
# 2                     36       AOC  80000       1220            3  40.669411
# 3                     36       AOC  80000       1220            4  40.669421
# 4                     36       AOC  80000       1220            5  40.669433
# ...                  ...       ...    ...        ...          ...        ...
# 5162876               32       MCL  40000        614          329  43.071944
# 5162877               32       MCL  40000        614          330  43.071933
# 5162878               32       MCL  40000        614          331  43.071922
# 5162879               32       MCL  40000        614          332  43.071911
# 5162880               32       MCL  40000        614          333  43.071899
#
#          longitude      n_lat      n_lon  seg_dist_ft
# 0       -73.829205  40.669405 -73.829203     1.734709
# 1       -73.829203  40.669411 -73.829200     2.408953
# 2       -73.829200  40.669421 -73.829196     3.639469
# 3       -73.829196  40.669433 -73.829190     4.522462
# 4       -73.829190  40.669448 -73.829184     5.894653
# ...            ...        ...        ...          ...
# 5162876 -73.771727  43.071933 -73.771760     9.501454
# 5162877 -73.771760  43.071922 -73.771792     9.609339
# 5162878 -73.771792  43.071911 -73.771825     9.743090
# 5162879 -73.771825  43.071899 -73.771858     9.565229
# 5162880 -73.771858        NaN        NaN          NaN
#
# [5162881 rows x 23 columns]

# %%
full['seg_speed_ft/s'] = full['seg_dist_ft']*4

full['seg_mph'] = 0.6818181818 * full['seg_speed_ft/s']

full['cum_dist_ft'] = full.groupby(['track_id', 'race_date', 'race_number', 
                              'program_number'])['seg_dist_ft'].cumsum()

full['avg_speed_ft/s'] = full['cum_dist_ft'] / (full['trakus_index']/4)

full['avg_mph'] = 0.6818181818 * full['avg_speed_ft/s']

full['seg_accel_ft/s2'] = 4 * full['seg_speed_ft/s'].diff()

full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5162881 entries, 0 to 5162880
# Data columns (total 29 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   track_id         object
#  1   race_date        datetime64[ns]
#  2   race_number      int64
#  3   program_number   object
#  4   weight_carried   float64
#  5   jockey           object
#  6   odds             float64
#  7   horse_id         int64
#  8   finishing_place  int64
#  9   horse_name       object
#  10  distance_id      int64
#  11  course_type      object
#  12  track_condition  object
#  13  run_up_distance  int64
#  14  race_type        object
#  15  purse            int64
#  16  post_time        int64
#  17  trakus_index     int64
#  18  latitude         float64
#  19  longitude        float64
#  20  n_lat            float64
#  21  n_lon            float64
#  22  seg_dist_ft      float64
#  23  seg_speed_ft/s   float64
#  24  seg_mph          float64
#  25  cum_dist_ft      float64
#  26  avg_speed_ft/s   float64
#  27  avg_mph          float64
#  28  seg_accel_ft/s2  float64
# dtypes: datetime64[ns](1), float64(13), int64(8), object(7)
# memory usage: 1.1+ GB

# %%
full = full[['track_id', 'race_date', 'race_number', 'program_number', 'horse_id', 'weight_carried', 
                'jockey', 'odds', 'finishing_place', 'horse_name', 'course_type', 'track_condition',
                'race_type', 'purse', 'post_time', 'latitude', 'longitude', 'n_lat', 'n_lon', 'distance_id', 
                'run_up_distance', 'trakus_index', 'seg_dist_ft', 'seg_speed_ft/s', 'seg_mph', 'cum_dist_ft', 
                'avg_speed_ft/s', 'avg_mph', 'seg_accel_ft/s2']]

# %%
import pickle

with open('../data/full_race_data.pickle', 'wb') as file:
    pickle.dump(full, file)

# %%
full.head(50)
# Out:
#    track_id  race_date  race_number program_number  horse_id  weight_carried  \
# 0       AQU 2019-01-01            1              1         1           123.0
# 1       AQU 2019-01-01            1              1         1           123.0
# 2       AQU 2019-01-01            1              1         1           123.0
# 3       AQU 2019-01-01            1              1         1           123.0
# 4       AQU 2019-01-01            1              1         1           123.0
# 5       AQU 2019-01-01            1              1         1           123.0
# 6       AQU 2019-01-01            1              1         1           123.0
# 7       AQU 2019-01-01            1              1         1           123.0
# 8       AQU 2019-01-01            1              1         1           123.0
# 9       AQU 2019-01-01            1              1         1           123.0
# 10      AQU 2019-01-01            1              1         1           123.0
# 11      AQU 2019-01-01            1              1         1           123.0
# 12      AQU 2019-01-01            1              1         1           123.0
# 13      AQU 2019-01-01            1              1         1           123.0
# 14      AQU 2019-01-01            1              1         1           123.0
# 15      AQU 2019-01-01            1              1         1           123.0
# 16      AQU 2019-01-01            1              1         1           123.0
# 17      AQU 2019-01-01            1              1         1           123.0
# 18      AQU 2019-01-01            1              1         1           123.0
# 19      AQU 2019-01-01            1              1         1           123.0
# 20      AQU 2019-01-01            1              1         1           123.0
# 21      AQU 2019-01-01            1              1         1           123.0
# 22      AQU 2019-01-01            1              1         1           123.0
# 23      AQU 2019-01-01            1              1         1           123.0
# 24      AQU 2019-01-01            1              1         1           123.0
# 25      AQU 2019-01-01            1              1         1           123.0
# 26      AQU 2019-01-01            1              1         1           123.0
# 27      AQU 2019-01-01            1              1         1           123.0
# 28      AQU 2019-01-01            1              1         1           123.0
# 29      AQU 2019-01-01            1              1         1           123.0
# 30      AQU 2019-01-01            1              1         1           123.0
# 31      AQU 2019-01-01            1              1         1           123.0
# 32      AQU 2019-01-01            1              1         1           123.0
# 33      AQU 2019-01-01            1              1         1           123.0
# 34      AQU 2019-01-01            1              1         1           123.0
# 35      AQU 2019-01-01            1              1         1           123.0
# 36      AQU 2019-01-01            1              1         1           123.0
# 37      AQU 2019-01-01            1              1         1           123.0
# 38      AQU 2019-01-01            1              1         1           123.0
# 39      AQU 2019-01-01            1              1         1           123.0
# 40      AQU 2019-01-01            1              1         1           123.0
# 41      AQU 2019-01-01            1              1         1           123.0
# 42      AQU 2019-01-01            1              1         1           123.0
# 43      AQU 2019-01-01            1              1         1           123.0
# 44      AQU 2019-01-01            1              1         1           123.0
# 45      AQU 2019-01-01            1              1         1           123.0
# 46      AQU 2019-01-01            1              1         1           123.0
# 47      AQU 2019-01-01            1              1         1           123.0
# 48      AQU 2019-01-01            1              1         1           123.0
# 49      AQU 2019-01-01            1              1         1           123.0
#
#          jockey   odds  finishing_place        horse_name  ... distance_id  \
# 0   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 1   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 2   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 3   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 4   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 5   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 6   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 7   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 8   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 9   Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 10  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 11  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 12  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 13  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 14  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 15  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 16  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 17  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 18  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 19  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 20  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 21  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 22  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 23  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 24  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 25  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 26  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 27  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 28  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 29  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 30  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 31  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 32  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 33  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 34  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 35  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 36  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 37  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 38  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 39  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 40  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 41  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 42  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 43  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 44  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 45  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 46  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 47  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 48  Dylan Davis  130.0                2  Sounds Delicious  ...         650
# 49  Dylan Davis  130.0                2  Sounds Delicious  ...         650
#
#    run_up_distance trakus_index  seg_dist_ft  seg_speed_ft/s    seg_mph  \
# 0               36            1     1.734709        6.938836   4.731024
# 1               36            2     2.408953        9.635811   6.569871
# 2               36            3     3.639469       14.557874   9.925823
# 3               36            4     4.522462       18.089850  12.333988
# 4               36            5     5.894653       23.578613  16.076327
# 5               36            6     6.820300       27.281199  18.600817
# 6               36            7     8.303640       33.214559  22.646290
# 7               36            8     9.376644       37.506575  25.572665
# 8               36            9     9.459504       37.838018  25.798649
# 9               36           10    10.503063       42.012251  28.644716
# 10              36           11    11.621558       46.486233  31.695159
# 11              36           12    11.926523       47.706092  32.526881
# 12              36           13    12.559809       50.239237  34.254025
# 13              36           14    12.510526       50.042105  34.119617
# 14              36           15    13.636212       54.544848  37.189669
# 15              36           16    13.235945       52.943778  36.098031
# 16              36           17    13.534960       54.139841  36.913528
# 17              36           18    14.221083       56.884332  38.784772
# 18              36           19    14.762837       59.051347  40.262282
# 19              36           20    14.875298       59.501190  40.568993
# 20              36           21    14.777041       59.108164  40.301021
# 21              36           22    14.851578       59.406310  40.504303
# 22              36           23    15.507724       62.030894  42.293791
# 23              36           24    15.655389       62.621557  42.696516
# 24              36           25    16.065447       64.261788  43.814856
# 25              36           26    16.291911       65.167646  44.432486
# 26              36           27    16.272306       65.089224  44.379016
# 27              36           28    16.117871       64.471483  43.957829
# 28              36           29    16.448715       65.794862  44.860133
# 29              36           30    16.898328       67.593311  46.086349
# 30              36           31    16.865985       67.463942  45.998142
# 31              36           32    16.899239       67.596956  46.088834
# 32              36           33    16.571274       66.285098  45.194385
# 33              36           34    16.975176       67.900704  46.295934
# 34              36           35    16.959078       67.836310  46.252030
# 35              36           36    16.972888       67.891553  46.289695
# 36              36           37    17.327952       69.311808  47.258051
# 37              36           38    17.134783       68.539133  46.731227
# 38              36           39    17.145063       68.580254  46.759264
# 39              36           40    17.352215       69.408861  47.324223
# 40              36           41    17.080227       68.320908  46.582438
# 41              36           42    17.188492       68.753968  46.877705
# 42              36           43    17.120094       68.480377  46.691166
# 43              36           44    17.588747       70.354990  47.969311
# 44              36           45    17.289204       69.156814  47.152373
# 45              36           46    17.220018       68.880073  46.963686
# 46              36           47    17.754429       71.017718  48.421171
# 47              36           48    17.166787       68.667148  46.818510
# 48              36           49    17.413064       69.652254  47.490173
# 49              36           50    17.455591       69.822364  47.606158
#
#     cum_dist_ft  avg_speed_ft/s    avg_mph  seg_accel_ft/s2
# 0      1.734709        6.938836   4.731024              NaN
# 1      4.143662        8.287323   5.650448        10.787900
# 2      7.783130       10.377507   7.075573        19.688254
# 3     12.305593       12.305593   8.390177        14.127902
# 4     18.200246       14.560197   9.927407        21.955053
# 5     25.020546       16.680364  11.372975        14.810343
# 6     33.324185       19.042392  12.983449        23.733441
# 7     42.700829       21.350414  14.557101        17.168064
# 8     52.160333       23.182370  15.806162         1.325773
# 9     62.663396       25.065358  17.090017        16.696931
# 10    74.284954       27.012711  18.417757        17.895929
# 11    86.211477       28.737159  19.593518         4.879436
# 12    98.771287       30.391165  20.721249        10.132578
# 13   111.281813       31.794804  21.678275        -0.788526
# 14   124.918025       33.311473  22.712368        18.010970
# 15   138.153969       34.538492  23.548972        -6.404277
# 16   151.688930       35.691513  24.335122         4.784250
# 17   165.910013       36.868892  25.137881        10.977965
# 18   180.672849       38.036389  25.933902         8.668059
# 19   195.548147       39.109629  26.665656         1.799374
# 20   210.325188       40.061941  27.314959        -1.572105
# 21   225.176766       40.941230  27.914475         1.192585
# 22   240.684489       41.858172  28.539663        10.498335
# 23   256.339878       42.723313  29.129532         2.362650
# 24   272.405325       43.584852  29.716945         6.560926
# 25   288.697237       44.414960  30.282927         3.623431
# 26   304.969543       45.180673  30.805004        -0.313690
# 27   321.087413       45.869630  31.274748        -2.470963
# 28   337.536129       46.556707  31.743210         5.293515
# 29   354.434457       47.257928  32.221314         7.193799
# 30   371.300442       47.909734  32.665728        -0.517479
# 31   388.199681       48.524960  33.085200         0.532058
# 32   404.770956       49.063146  33.452145        -5.247433
# 33   421.746131       49.617192  33.829904         6.462424
# 34   438.705209       50.137738  34.184821        -0.257574
# 35   455.678097       50.630900  34.521068         0.220969
# 36   473.006049       51.135789  34.865311         5.681021
# 37   490.140832       51.593772  35.177572        -3.090698
# 38   507.285896       52.029323  35.474538         0.164482
# 39   524.638111       52.463811  35.770780         3.314430
# 40   541.718338       52.850570  36.034479        -4.351811
# 41   558.906830       53.229222  36.292651         1.732238
# 42   576.026924       53.583900  36.534477        -1.094363
# 43   593.615672       53.965061  36.794360         7.498451
# 44   610.904875       54.302656  37.024538        -4.792702
# 45   628.124893       54.619556  37.240606        -1.106966
# 46   645.879323       54.968453  37.478491         8.550581
# 47   663.046110       55.253842  37.673074        -9.402280
# 48   680.459173       55.547688  37.873423         3.940426
# 49   697.914765       55.833181  38.068078         0.680440
#
# [50 rows x 29 columns]
